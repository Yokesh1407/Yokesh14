# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
def My_api():
    api_key = 'AIzaSyAVnh_zrhDH0_q98vqjmaelu8cqvHAXRT4' #my API Key youtube
    youtube = build('youtube', 'v3', developerKey=api_key) 
    return youtube
    
youtube = My_api()

# %%
#Channel API's

channel_id = 'UCTxfYLmM82aMCovQexkRxFQ'  # channel ID : CHERRY_VLOGS
#channel_id = 'UCJcCB-QYPIBcbKcBQOTwhiA' #VJ siddhu
#channel_id = 'UCYqXh1HzJSYYYmbaoK4veDw' #HOBBY EXPLORER
#channel_id = 'UCvyZS6W6zMJCZBVzF-Ei6sw' #a2d
#channel_id = 'UCi3o8sgPl4-Yt501ShuiEgA' #finally
#channel_id = 'UCWKAAgM5L7bExQJkPZIbiaw' #Tamiltrekker

# %%
#getting channel details using def function
def get_channel(channel_id):
    channel_request = youtube.channels().list( #function to get api data from youtube using channelid and lists
    id=channel_id,
    part='snippet,statistics,contentDetails'
)
    channel_response = channel_request.execute() #execute all the data of the channel in api

    """ print(channel_response.keys())

    print(channel_response['items']) show all the data's present inside items """

    for i in channel_response["items"]:
        channel_informations = {
            'channel_name' : i['snippet']['title'],
            'channel_id' : i['id'],
            'Subcriber_count' : i['statistics']['subscriberCount'],
            'Channel_views' : i['statistics']['viewCount'],
            'Total_Videos':i["statistics"]["videoCount"] if 'statistics' in i and 'videoCount' in i['statistics'] else None,
            'Channel_description' : i['snippet']['description'],
            'Playlist_id' : i['contentDetails']['relatedPlaylists']['uploads']
         }

    return channel_informations

channel_details = get_channel(channel_id) 
print(channel_details)
# Out:
# {'channel_name': 'Cherry Vlogs', 'channel_id': 'UCTxfYLmM82aMCovQexkRxFQ', 'Subcriber_count': '1390000', 'Channel_views': '217516444', 'Total_Videos': '853', 'Channel_description': 'Thank you for visiting till here!!!\nI’m an engineer who turned into a full time Tamil Vlogger.  I started this channel in my college days to share my interests on motorcycles and travel but slowly it became my life dairy. Most of the content I release in the channel goes through a good hard work and passion. So guys stay tuned for many more Motovlogs, Travel vlogs, informative and lifestyle vlogs. \nYours lovingly,\nTagore Sureshbabu \n\nSubscribe and hit the Bell Icon to become a Part on cherry vlogs family.\n', 'Playlist_id': 'UUTxfYLmM82aMCovQexkRxFQ'}

# %% [markdown]
# #PLAYLIST ID DATA

# %%
#Getting Playlist id data

def get_videoIDs(channel_id):
    videos_IDlists =[]
    playlist_request = youtube.channels().list( #function to get api data from youtube using channelid and contentdetails
        id=channel_id,
        part='contentDetails') #inside contentdetail only playlist is present

    playlist_response = playlist_request.execute()

    playlist_id = playlist_response['items'][0]['contentDetails']['relatedPlaylists']['uploads'] # 'UUJcCB-QYPIBcbKcBQOTwhiA' - VJ SIDDHU playlist id

    next_page_token =None

    #getting all the video ids

    while True:
        playlistitem_request = youtube.playlistItems().list(
            part="snippet",                      #inside snippet only we have playlistId so we are mapping with our playlist_id 
            playlistId=playlist_id,  
            maxResults = 50,
            #The maxResults parameter specifies the maximum number of items that should be returned in the result set. Acceptable values are 0 to 50, inclusive. The default value is 5.
            pageToken = next_page_token   #pagetoken will retreive the next page data used to navigate next page data taking maxcounts eg 50,100,150
        )
        playlistitem_response = playlistitem_request.execute()

        for i in range(len(playlistitem_response['items'])): #len(playlistitem_response['items']) value will be 50 and next cycle next 50 because we gave maxResult as 50 using it to get all video ids
            videos_IDlists.append(playlistitem_response['items'][i]['snippet']['resourceId']['videoId']) #inserting into empty list
        next_page_token = playlistitem_response.get('nextPageToken') #get function will return if we have value if we don't have values it will return null
    
        if next_page_token is None: 
            break
    #playlistitem_response['items'][0]['snippet']['resourceId']['videoId'] this will give videoId's data this data is appended in empty list
    return videos_IDlists
    #print(playlistitem_response) #will show the playlist id data's
        #print(videos_IDlists) will show all the video ids
        #print(len(videos_IDlists)) will show count of all the video ids

# %%
videos_ids_all = get_videoIDs(channel_id)

# %%
videos_ids_all
# Out:
# ['2xnCG2OuqfE',
#  'yQ45vIHpWxc',
#  '1zBuKn3KXFg',
#  'fc1bD5SQvkk',
#  'kn4vQ-uG4Kw',
#  'U5saYYiQ5b8',
#  's15KKauqS4E',
#  'UTXYgCKS7Hg',
#  'rq7Rp6_3aXk',
#  'yScV-YwTnEk',
#  'H7K4N8mSCc4',
#  'p5Ix1Faz1Hw',
#  'MBR4kefV3wI',
#  '1PrJNVW16UY',
#  'EKyT8SVo89s',
#  'XDF6sPFPO3U',
#  'PXzT3bVlFNk',
#  'tIMDNFKKq74',
#  '3Hi7I81gtXs',
#  'Ked0saxns6Q',
#  'baxuANxNlfI',
#  'ZoI2wfj_OX0',
#  'PKUCLg6xOeY',
#  'u9tDHRYUJok',
#  'qPyhETU3VjA',
#  'sCq4qwwVmx0',
#  '301HsAA3z1c',
#  'szatZqT3B94',
#  'ObJvAJbe8HY',
#  'c1HX_EbZYAo',
#  'o-Cc6jq916M',
#  'RMwC_4oxKT0',
#  'cu_kqf70vEg',
#  '6ZX8gywf6sQ',
#  'oVHwoZaMD-s',
#  'fT9yAjUHzwQ',
#  'qltm-ak_OKo',
#  'G7gaf4MjN4o',
#  'zXWvYpc3QCE',
#  'HN54x-eShFU',
#  'J9-hDP9Lu1g',
#  '4NppfA06-_s',
#  '6l55q7r4MGU',
#  'FV9xIo7Umlg',
#  'dbsv8HPT2Ww',
#  '3q6-_eROVDA',
#  'zcaOimCOsmQ',
#  'YrXAUN3p1IM',
#  'nXklZKUebSs',
#  'tLMoqfR-qCQ',
#  'QIGYf2erUHo',
#  'NPMjsLOPN70',
#  'EQKYyL6ycSM',
#  '1dOwdBY3szA',
#  'VqDTwjnY8lg',
#  'EUeu-GJyuYw',
#  's5RDMG_tUao',
#  'dSPbSzYYDWM',
#  '8Han8BxvowY',
#  'kDpxPWeRnc8',
#  'P9HFWTJ4-xE',
#  'uyWVgA5tyrM',
#  'W2gKC1ZIQGU',
#  'sqqn5v1lgYI',
#  'clW5w4Da6bo',
#  'owq8pBKJjN0',
#  'Kw_Wq3kGmYg',
#  '_KdnWXvqX9w',
#  'snsgnHhqzbA',
#  'SMiDWZfHEXI',
#  'NorgkUtR6qk',
#  '-uNo-wCb6uc',
#  'iWxDeOPZL1w',
#  'ilOdl7yrF_Y',
#  'F_5yH9-9cig',
#  'z94RB8446A0',
#  'QvLelz6dPTY',
#  'VW8HFecxb68',
#  'bfsPCK5BlXI',
#  'EiXBbGZZnYY',
#  '1qAHPXYvdiA',
#  'xdeVjROwFEc',
#  'bX83aS2wClI',
#  'bIr9h7jtXXk',
#  'mLiuvVXfUII',
#  'cewmYVENXjk',
#  '533epbdavzA',
#  'xMd4Q8hzldM',
#  'yNNkkuGNDhQ',
#  'E3H0vX8x9M8',
#  'i87u4H95el8',
#  'E_J1yci5dbo',
#  'z3TdxPFm-L0',
#  'te5MIYgzFRo',
#  'ssc8mX5eByI',
#  '6htKQ9m5gVM',
#  'kJmUaD6RnhQ',
#  'LYBCxqlSFJk',
#  'XeEQ5shaG88',
#  'ksyBX4Ix32s',
#  'hTTFUvpxrqE',
#  'GavbgrCfSiw',
#  't_8zbyPykgQ',
#  'VJaAKKPLmsg',
#  'ZGLIUS9WB8A',
#  'U_Sj6vRJkLQ',
#  'WDAOs8vXf4M',
#  'OecMmdkX4L0',
#  '8zo-lb7LvGA',
#  'qivlE1Hy3dQ',
#  'CmQgdGcqy_s',
#  '0gP4BWpl5Lw',
#  'hBLoCsCmXkE',
#  'tXDnHMlsZ4U',
#  'dQf5xtW5UYk',
#  'WPLHElwsPPU',
#  '4jMwYwtMR3s',
#  '3OcucZQcG_8',
#  'csv6Y8x6BRU',
#  'd52kp676npI',
#  'GfmQ6mzzly0',
#  '9jovCSAeaBo',
#  'TyMsPyNQcA8',
#  'Ucx2i_TufNk',
#  'FVCZ8NPAytY',
#  'YHv9RXnr7XY',
#  'nO43MjCLW0A',
#  'IoJ8nkSCuo8',
#  'TrisAUXFK8o',
#  '8yAsHJrGFLg',
#  'L7AzOlTLHd4',
#  'UFnxxxldXqg',
#  'R_dzTQywdek',
#  '1OKP6dWX_xM',
#  'igvUpCEALzI',
#  'r7Rx9I0Al8E',
#  '0IVBovKGSdE',
#  'v1arwXMvv1o',
#  'T-pjqLcbn0Q',
#  'Oi_PI9mWT0A',
#  'WyeltJstELE',
#  'zlKEjwZ1WCY',
#  '-XC-ZZQTFTc',
#  'm3MLYRgIb6k',
#  'P5cndHjeMek',
#  'vZGsef4gAZg',
#  'P6aeNk0KqhU',
#  'FZOWUCLG9cI',
#  '55FJ8S5GJQw',
#  'jpxNuluiy8U',
#  'yfwnpF_YB38',
#  '7k9Rt0sRCDQ',
#  'ji2qL2k18P4',
#  '3TYJLzh47zE',
#  'nMMPnXQpTB4',
#  'TrIvXer5EpY',
#  'mTj7xYaG4k4',
#  '5PN73jENxzA',
#  'SPyVuauAYrU',
#  '2dXX3BmcMAw',
#  'qD1e60R-mJI',
#  'UKbg8CEEmmA',
#  'tQ4l4GH1zAc',
#  'AJ4J6soRGQg',
#  'FBZFmBcm-lw',
#  '7f8GkhCakxs',
#  'N6hC1j2p8HI',
#  'O_eCMDtruLI',
#  '2KtPwmjqtBk',
#  'OkuCdKIYzX0']

# %%
len(videos_ids_all)
# Out:
# 170

# %% [markdown]
# #Get video informations / details

# %%
#get video informations / details
def get_video_details(videos_ids_all):
    video_data=[]
    for video_id in videos_ids_all:
        request=youtube.videos().list(
        part="snippet,ContentDetails,statistics",
        id=video_id
    )
        video_response=request.execute()

        for item in video_response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                Channel_Id=item['snippet']['channelId'],
                Video_Id=item['id'],
                Title=item['snippet']['title'],
                Tags=item['snippet'].get('tags'), #using get because the sometimes it won't be present
                Thumbnail=item['snippet']['thumbnails']['default']['url'],
                Description=item['snippet'].get('description'),
                Published_Date=item['snippet']['publishedAt'],
                Duration=item['contentDetails']['duration'],
                Views=item['statistics'].get('viewCount'),
                Likes=item['statistics'].get('likeCount'),
                Comments=item['statistics'].get('commentCount'),
                Favorite_Count=item['statistics']['favoriteCount'],
                Definition=item['contentDetails']['definition'],
                Caption_Status=item['contentDetails']['caption']
        )
        video_data.append(data)
    return video_data

# %%
video_details = get_video_details(videos_ids_all)

# %%
video_details
# Out:
# [{'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'SiJDnJ2get8',
#   'Title': '🥢🍜 Chinese chopsticks',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'chopsticks',
#    'how to use chopsticks',
#    'use chopsticks',
#    'how to use chopsticks correctly',
#    'how to hold chopsticks',
#    'chopsticks tutorial',
#    'learn chopsticks',
#    'easy way to use chopsticks',
#    'chopstick seasy to use',
#    'chopstick',
#    'the best way to use chopsticks.',
#    'single use',
#    'how to eat with chopsticks',
#    'japanese chopsticks',
#    'Bamboo chopsticks',
#    'Re-usable chopsticks',
#    'Asian\xa0chopsti',
#    'history of chopsticks'],
#   'Thumbnail': 'https://i.ytimg.com/vi/SiJDnJ2get8/default.jpg',
#   'Description': "After going to Chinatown night market. I was still hungry. \nSo we went to this Chinese restaurant in the chinatown. \nWatch this week Friday's Chinatown night market full video on Instagram. \n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-26T10:30:12Z',
#   'Duration': 'PT37S',
#   'Views': '75356',
#   'Likes': '5947',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': '6D5n69LYa2M',
#   'Title': '🏮 Chinatown night market in USA 🇺🇸',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'nightlife',
#    'nightlife in usa',
#    'nightlife in america',
#    'life in usa',
#    'night market',
#    'night market food',
#    'Chinatown in usa',
#    'Tamil USA Vlog',
#    'Day in my life',
#    'chinatown',
#    'chinatown usa',
#    'chinatowns in usa',
#    'usa',
#    'san francisco chinatown',
#    'chinatowns in us',
#    'chinatown in america',
#    'chinatown in united states',
#    'chinatowns',
#    'best food in chinatown san francisco',
#    '10 best chinatowns in the world'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6D5n69LYa2M/default.jpg',
#   'Description': "Every second Friday of the month. San Francisco Chinatown is hosting a night market, where small businesses sell their stuff on the street. \nAbout 4 or 5 blocks of street is blocked for this festival. \nThere were so many people shoulder to shoulder. \nLots of food to try. \n\nChapters:\n00:00 Dramatic Intro 🤣\n00:47 Arrived at Chinatown\n03:39 Mooncake\n07:05 Outro byeeee... \n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-26T10:30:02Z',
#   'Duration': 'PT7M38S',
#   'Views': '6972',
#   'Likes': '324',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'JrlyN_UTmKE',
#   'Title': '🚕 Tesla Cybertruck full video podalama?',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'டெஸ்லா சைபர்ட்ரக்',
#    'machine learning',
#    'deep learning',
#    'machine learning vs ai',
#    'machine learning course',
#    'machine learning engineer',
#    'self driving',
#    'self driving cars',
#    'self driving car',
#    'full self driving',
#    'driving',
#    'self driving technology',
#    'tesla self driving',
#    'self diving',
#    'tesla cybertruck',
#    'cybertruck',
#    'tesla truck',
#    'tesla cybertruck pov',
#    'cybertruck tesla',
#    '2024 tesla cybertruck',
#    'AI&DS'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JrlyN_UTmKE/default.jpg',
#   'Description': "🚕 Tesla Cybertruck full video podalama? illa time waste ah? \n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-21T03:30:10Z',
#   'Duration': 'PT29S',
#   'Views': '491729',
#   'Likes': '36892',
#   'Comments': '401',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'jnO_MdYw7Pk',
#   'Title': '🚗 Driving in India vs driving in USA',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'driving in usa',
#    'driving in the usa',
#    'driving in america',
#    'driving in the usa for the first time',
#    'usa',
#    'Driving in India',
#    'கார் டிரைவர்',
#    'சாலை',
#    'india',
#    'driving',
#    'driving in india',
#    'crazy driving in india',
#    'tourist driving in india',
#    'foreigner driving in india',
#    'how to drive in india',
#    'driving in india crazy',
#    'driving in india traffic',
#    'american driving in india',
#    'india driving'],
#   'Thumbnail': 'https://i.ytimg.com/vi/jnO_MdYw7Pk/default.jpg',
#   'Description': "🚦 solluveengala matingala?\n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-20T10:30:24Z',
#   'Duration': 'PT35S',
#   'Views': '803014',
#   'Likes': '59202',
#   'Comments': '237',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'uv902wMftUg',
#   'Title': 'Passive income is overrated 😰 Pursue active income instead ✅',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'active income vs passive',
#    'passive income ideas 2024',
#    'passive income work from home',
#    'work from home jobs',
#    'photoshop',
#    'graphic design',
#    'video editing jobs',
#    'adobe primer pro',
#    'skill',
#    'labor',
#    'skill based business',
#    'upskilling',
#    'active income ideas',
#    'remote jobs 2024',
#    'வீட்டில் இருந்து வேலை',
#    'செயலற்ற வருமான யோசனைகள்',
#    'financial planning',
#    'basic financial discipline',
#    'நிரந்தர வருமானம்',
#    'ஒழுக்கம்'],
#   'Thumbnail': 'https://i.ytimg.com/vi/uv902wMftUg/default.jpg',
#   'Description': "Passive income is dead, pursue active income instead.💀 \n\nIn this video I've explained two paths you could pursue actively to earn a living today, tomorrow. \nThese are straight forward ways that takes years to develop. So don't expect to get rich tomorrow afternoon. \n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-19T10:30:30Z',
#   'Duration': 'PT10M56S',
#   'Views': '30538',
#   'Likes': '1334',
#   'Comments': '136',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'pFt9qbal9dM',
#   'Title': 'Earth day April 22 ☕️ Coffee shop mug rental 🍵',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'coffee',
#    'rental',
#    'coffee cup',
#    'coffee cups',
#    'cooffee and tea rental',
#    'rental property',
#    'coffee cup organizer',
#    'paper cup',
#    'environmental impact',
#    'sustainability',
#    'environment sustainability',
#    'urban sustainability',
#    'sustainability explained',
#    'environmental sustainability',
#    'sustainability goals',
#    'global sustainability',
#    'sustainability project',
#    'sustainability environment',
#    'okapi',
#    'mug rental app'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pFt9qbal9dM/default.jpg',
#   'Description': "☕️ Can we try taking our own mug to our local coffee shop?\n\n🥤 50 billion paper cups are thrown out each year. \n🥤 Almost all of them have some form of synthetic coating on top of it. We are ingesting those microplastics. 😰 \n\n🥤 Video made by Hobby & Explorer(Our editor)\n\n🥤 Hobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\n🥤 Facebook: https://www.facebook.com/HobbyExplorer\n🥤 English Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-16T10:30:15Z',
#   'Duration': 'PT41S',
#   'Views': '523226',
#   'Likes': '39869',
#   'Comments': '152',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'kWm-NdAwOX0',
#   'Title': '🍄 Kovai Cafe in California',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'Kovai cafe',
#    'tamil food in usa',
#    'usa tamil restaurant',
#    'dosai',
#    'anjappar california',
#    'A2B california',
#    'Saravana Bhavan California',
#    'அஞ்சப்பர்',
#    'அமெரிக்காவில் உள்ள தமிழ் உணவகம்',
#    'தோசை',
#    'சட்னி',
#    'இட்லி',
#    'full meals',
#    'limited meals',
#    'tamil vlogs',
#    'usa tamil',
#    'tamil usa channel',
#    'tamil restaurant in usa',
#    'chettinad cuisine',
#    'kaaraikudi restaurant',
#    'usa tamil food',
#    'us tamil food vlog',
#    'hobby explorer food'],
#   'Thumbnail': 'https://i.ytimg.com/vi/kWm-NdAwOX0/default.jpg',
#   'Description': "📍 Kovai Cafe, San Jose, California\nLiked their Lunch & fresh dosa for breakfast, \nI am yet to try their street style mushroom 🍄\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-15T10:30:15Z',
#   'Duration': 'PT38S',
#   'Views': '1547497',
#   'Likes': '118314',
#   'Comments': '266',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'aePiQsu-dz0',
#   'Title': 'Friday 8pm Live Q&A',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'live',
#    'Q&A',
#    'Subscriber questions',
#    'ms in usa',
#    'export to usa',
#    'travel and tourism to USA',
#    'Europe travel',
#    'euro trip',
#    'education',
#    'career',
#    'India to USA',
#    'MS in Computer Science',
#    'AI&DS',
#    'Artificial Intelligence Career',
#    'Data Science',
#    'Engineering',
#    'BTech vs BE',
#    'BE AI&DS',
#    'generative ai',
#    'sora',
#    'usa universities',
#    'MS Student',
#    'data science',
#    'open ai',
#    'Engineering colleges in Chennai',
#    'USA Universities'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aePiQsu-dz0/default.jpg',
#   'Description': '📧 Questions@HobbyExplorer.com\nYou can also post your questions in chat box during the live session. \n\nPointers: \n✈️ Education - MS in US\n✈️ Business - Export to USA\n✈️ Travel - US & Europe\n\nSee you Friday at 8pm Indian Time. 👋',
#   'Published_Date': '2024-04-12T17:30:50Z',
#   'Duration': 'PT50M25S',
#   'Views': '194264',
#   'Likes': '412',
#   'Comments': '26',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'rLhPbqmCeSI',
#   'Title': 'How to plan Europe Trip 🇨🇭✈️🚊',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Malaysia',
#    'Switzerland',
#    'New York nagaram song',
#    'SIM card',
#    'hola fly',
#    'Europe travel plan',
#    'Europe travel tips',
#    'itinerary',
#    'Europe visa experience',
#    'flight booking',
#    'hotel booking',
#    'travel insurance',
#    'food',
#    'accommodation',
#    'things to take to Europe',
#    'Germany currency conversion',
#    'credit card transaction fees',
#    'experiences',
#    'airbnb',
#    'hostels',
#    'packing tips for Europe',
#    'us to Europe',
#    'Europe travel plan in tamil',
#    'Schengen visa',
#    'NRI'],
#   'Thumbnail': 'https://i.ytimg.com/vi/rLhPbqmCeSI/default.jpg',
#   'Description': "Published a detailed video YouTube about \nEurope Visa Experience\nItinerary \nFlight booking\nHotel booking\nTravel Insurance\nSIM Card\nTransportation\nFood Problem\nThings to take\nCurrency conversion\nCredit Card\nExperiences\nPacking\n\nCheck on the channel Explorers!\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-12T10:30:18Z',
#   'Duration': 'PT28S',
#   'Views': '175532',
#   'Likes': '14162',
#   'Comments': '66',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'V-G0gE4lxgE',
#   'Title': 'How to plan Europe Trip 🇨🇭✈️🚊',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Malaysia',
#    'Switzerland',
#    'New York nagaram song',
#    'SIM card',
#    'hola fly',
#    'Europe travel plan',
#    'Europe travel tips',
#    'itinerary',
#    'Europe visa experience',
#    'flight booking',
#    'hotel booking',
#    'travel insurance',
#    'food',
#    'accommodation',
#    'things to take to Europe',
#    'Germany currency conversion',
#    'credit card transaction fees',
#    'experiences',
#    'airbnb',
#    'hostels',
#    'packing tips for Europe',
#    'us to Europe',
#    'Europe travel plan in tamil',
#    'Schengen visa',
#    'NRI'],
#   'Thumbnail': 'https://i.ytimg.com/vi/V-G0gE4lxgE/default.jpg',
#   'Description': 'Chapters: \n00:00 In this video\n00:20 Intro\n01:00 Europe Visa Experience\n03:43 Itinerary\n05:48 Flight tickets\n06:51 Hotel, Airbnbs & Hostel bookings\n08:22 Tea Break ☕️\n08:56 Travel Insurance \n10:10 Travel SIM card Hola Fly. \n11:48 Transportation - Car, Bus, Rental Car\n13:25 Food problem \n15:27 Things to take - converter, power bank\n16:34 Clothing - Winter jacket\n16:46 Currency Conversion \n18:12 Packing - Rolling\n19:01 More tips and tricks in comments\n\nHow to fill the visa form?\nhttps://www.youtube.com/watch?v=PL8PB1bij-E\n\nInsurance I used second time: IMG\n\nMy English Channel: https://www.youtube.com/@Hobby_Explorer',
#   'Published_Date': '2024-04-12T10:30:15Z',
#   'Duration': 'PT19M35S',
#   'Views': '38682',
#   'Likes': '1468',
#   'Comments': '110',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'JdTz6q3REvI',
#   'Title': 'Live Q&A education, business and travel',
#   'Tags': ['hobby explorer latest video',
#    'Hobby',
#    'Explorer',
#    'Tamil',
#    'Tamizh',
#    'Chennai',
#    'USA',
#    'Canada',
#    'Singapore',
#    'Srilanka',
#    'Malaysia',
#    'live',
#    'Q&A',
#    'Subscriber questions',
#    'ms in usa',
#    'export to usa',
#    'travel and tourism to USA',
#    'Europe travel',
#    'euro trip',
#    'education',
#    'career',
#    'India to USA',
#    'MS in Computer Science',
#    'AI&DS',
#    'Artificial Intelligence Career',
#    'Data Science',
#    'Engineering',
#    'BTech vs BE',
#    'BE AI&DS',
#    'generative ai',
#    'sora',
#    'usa universities',
#    'MS Student',
#    'MBBS to USA',
#    'USMLE',
#    'matched',
#    'business in usa',
#    'starting a business in usa'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JdTz6q3REvI/default.jpg',
#   'Description': 'Chapters:\n01:26 Internship interview callback problem\n3:25 Resume for university applications in USA\n5:17 Did the doctor get matched. \n6:35 George mason university\n8:50 Thumbnail editor\n9:40 Where to study India or USA? \n12:15 One year career gap\n13:55 GRE & IELTS Materials\n14:19 Commerce students scope\n15:14 15 year old AI Research assistant\n15:38 Incoming graduate student CS student offering help\n16:04 B.E. or B.Tech?\n16:50 Education in Germany\n17:13 12th completed what to choose in Engineering\n19:55 Thank you for the 100 rupees\n20:19 What degree to study to get a job in USA? \n22:33 Strict regulations for Green Card MS in US still worth it? \n26:55 Business EB-5 Visa \n29:40 Love you too!\n29:53 Need more Medical content\n30:04 Settling in USA after 12th\n31:30 MS for Mechanical Engineering students\n31:45 Apple Robot and Tesla Bot for washing dishes and clothes\n32:45 Bsc Agriculture Student H2b?\n33:50 Masters in Mechanical and Robotics\n34:09 Impact of AI in USA\n35:07 Handmade and Eco-friendly products in USA\n38:17 Business Paid Collaborations. Please email\n39:09 Education questions. Students thoongalaya neenga\n39:33 Love you too!!!!!!!!!!!\n39:40 US does not care about your 12th mark for MS\n40:51 14 year old learning full stack development\n42:27 F1 Miami Grand prix\n\nPost your questions about \n\nEducation - MS in US\nBusiness - Exports\nTravel - US & EU\n\nOr Email your questions to Questions@HobbyExplorer.com',
#   'Published_Date': '2024-04-10T17:18:39Z',
#   'Duration': 'PT43M30S',
#   'Views': '14976',
#   'Likes': '696',
#   'Comments': '44',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': '1CNw1JbDPJg',
#   'Title': '🌗 🌙 Solar eclipse in USA',
#   'Tags': ['சூரிய கிரகணம்',
#    'சந்திர கிரகணம்',
#    'மூட நம்பிக்கை',
#    'solar eclipse',
#    'april 8th',
#    'eclipse',
#    'solar eclipse 2024',
#    'eclipse solar',
#    'eclipse 2024',
#    'solar',
#    'total eclipse',
#    'solar eclipse live',
#    '2024 solar eclipse',
#    'ohio solar eclipse',
#    'Nasa',
#    'Eclipse chasers',
#    'eclipse chasers',
#    'total solar eclipse',
#    'eclipse chaser',
#    'eclipse chasing',
#    'solar eclipse in USA',
#    'hobby explorer latest video',
#    'usa',
#    'canada',
#    'path of totality',
#    'sun',
#    'moon',
#    'earth',
#    'solar system',
#    'animals',
#    'Bangalore',
#    'Chennai',
#    'Hyderabad',
#    'news today',
#    'knowledge',
#    'NRI'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1CNw1JbDPJg/default.jpg',
#   'Description': "🌗 🌙 After watching the solar eclipse I immediately made this video.\n🌗 🌙 So this video might be cursed. I think you should take a bath now.\n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-10T02:30:08Z',
#   'Duration': 'PT39S',
#   'Views': '354483',
#   'Likes': '28080',
#   'Comments': '115',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'gzOF5bpsWtQ',
#   'Title': '🏆 ⚪️ Idli vs Dosai 🟠',
#   'Tags': ['hobby explorer tamil',
#    'hobby explorer',
#    'இட்லி',
#    'இட்லி vs தோசை',
#    'தோசை',
#    'இட்லி மாவு',
#    'சுவையான இட்லி',
#    'இட்லி சாம்பார்',
#    'இட்லி benefits',
#    'idli vs dosa',
#    'இட்லிமாவு',
#    'கார சட்னி',
#    'தோசைமாவு',
#    '#வெள்ளசோளம்இட்லி',
#    'dosa',
#    'idli dosa batter',
#    'soft idli dosa batter',
#    'idli dosa',
#    'homemade idli dosa batter',
#    'dosa batter',
#    'dosas',
#    'homemade idli dosa',
#    'World idli festival',
#    'Bay area indian festival',
#    'shastha foods',
#    'bay area festival',
#    'indian festival in usa'],
#   'Thumbnail': 'https://i.ytimg.com/vi/gzOF5bpsWtQ/default.jpg',
#   'Description': "🏆 Intense fight between idli and dosa.\nDosa won. 🥇\nIdli is number 2 🥈\n\nAppearances in this video: \n@DrPal \n@Rangarajmadhampatty\n@CaliforniaKalaingan\n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-09T10:30:13Z',
#   'Duration': 'PT38S',
#   'Views': '1126959',
#   'Likes': '61689',
#   'Comments': '468',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'UlvRKFUVvSc',
#   'Title': '🇺🇸America-ல solar eclipse ☀️🌗🌛🌚 அமெரிக்காவில் சூரிய கிரகணம்',
#   'Tags': ['hobby explorer tamil',
#    'அமெரிக்காவில் சூரிய கிரகணம்',
#    'live stream',
#    'solar eclipse',
#    'total solar eclipse',
#    'solar eclipse 2024',
#    'total solar eclipse 2024',
#    'eclipse',
#    'solar eclipse live',
#    'april 8 solar eclipse',
#    '2024 solar eclipse path',
#    '2024 eclipse',
#    'solar eclipse glasses',
#    'solar eclipse april 8 2024',
#    'april 8 2024 solar eclipse',
#    'april 8th 2024 solar eclipse',
#    'sun eclipse',
#    "april's total solar eclipse live",
#    'lunar eclipse',
#    'eclipse april 8 2024',
#    'lunar eclipse 2024',
#    'eclipse nasa'],
#   'Thumbnail': 'https://i.ytimg.com/vi/UlvRKFUVvSc/default.jpg',
#   'Description': 'Today we experienced total solar eclipse at some parts of USA. Of-course I did not see it with my real eyes 👀 I used a polarized sunglasses and iPhone camera.',
#   'Published_Date': '2024-04-08T18:29:19Z',
#   'Duration': 'PT5M40S',
#   'Views': '28646',
#   'Likes': '723',
#   'Comments': '28',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'yhmEe2pa9a0',
#   'Title': '🦆Rivers, Creeks & Canals in Europe🌎',
#   'Tags': ['hobby explorer tamil',
#    'hobby explorer',
#    'europe creeks',
#    'creek',
#    'belgium boat ride',
#    'belgium',
#    'europe',
#    'tourism',
#    'europe travel',
#    'top places to visit in europe',
#    'travel vlog',
#    'பெல்ஜியம் படகு சவாரி',
#    'ஐரோப்பா சிற்றோடைகள்',
#    'கால்வாய்கள்',
#    'ஐரோப்பாவில் சுற்றுலா',
#    'boat ride',
#    'boat',
#    'belgium travel guide',
#    'boat tour',
#    'bruges belgium',
#    'ride',
#    'boat trip',
#    'belgium travel',
#    'bruges boat tour',
#    'bruges canal boat ride',
#    'historical boat tour in belgium',
#    'boat ride on canals of bruges',
#    'brugge belgium',
#    'canal boat'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yhmEe2pa9a0/default.jpg',
#   'Description': "🛶 There are so many boat rides in Europe.\n🚤 It's not just for sightseeing. They are actually using the creeks and canals for their own productivity and transportation.\n🚣 Several businesses depend on the rivers, creeks and canals being clean and functional.\n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-08T10:30:27Z',
#   'Duration': 'PT34S',
#   'Views': '320822',
#   'Likes': '25680',
#   'Comments': '139',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': '3jrPt0x5H7c',
#   'Title': '🌸 San Francisco Flower market 💐',
#   'Tags': ['hobby explorer tamil',
#    'கோயம்பேடு பூ சந்தை',
#    'கோயம்பேடு பூ மார்க்கெட்',
#    'koyambedu flower market | கோயம்பேடு பூ மார்க்கெட்',
#    '#கோயம்பேடுபூமார்க்கெட்',
#    'கோயம்பேடு பூ மார்க்கெட்டில் இருந்து வந்த ஒருவருக்கு கொரோனா வைரஸ் தொற்று உறுதியால் பரபரப்பு',
#    'koyambedu flower market',
#    'koyambedu flower market chennai',
#    'koyambedu poo market',
#    'flower market',
#    'san francisco flower market',
#    'san francisco flower mart',
#    'san francisco',
#    'flower mart',
#    'flowers',
#    'flowers in san francisco',
#    'flower',
#    'flower market fair'],
#   'Thumbnail': 'https://i.ytimg.com/vi/3jrPt0x5H7c/default.jpg',
#   'Description': '🌺 110 year old permanent flower market in San Francisco.',
#   'Published_Date': '2024-04-06T10:30:02Z',
#   'Duration': 'PT38S',
#   'Views': '219173',
#   'Likes': '14872',
#   'Comments': '82',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'T_ecppb3dho',
#   'Title': "How to setup YouTube Studio lights 💡 - Hobby Explorer's Garage Studio",
#   'Tags': ['hobby explorer tamil',
#    'youtube studio setup at home',
#    'lighting for youtube videos',
#    'how to light a youtube video',
#    'light setup',
#    'smart lights',
#    'aputure lights',
#    'rim light',
#    'hair light',
#    'aputure light review',
#    'how to use a fill light',
#    'how to light a set',
#    'how to use rim light',
#    'cheapest video light',
#    'aputure light dome se',
#    'aputure light dome se softbox',
#    'light dome se setup',
#    'key light',
#    'fill light',
#    'godox',
#    'small rig',
#    'amaran 200xs',
#    'amaran 200d',
#    'amaran 60d',
#    'amaran 60xs',
#    'garage',
#    'ஒளிப்பதிவு'],
#   'Thumbnail': 'https://i.ytimg.com/vi/T_ecppb3dho/default.jpg',
#   'Description': "Welcome to Hobby garage!!!!!!\nToday, \nI am setting lights for our YouTube studio in the garage. Before and after thumbnail summa dramatic ah vechen 🤣\nBut I like how the setup turned out. \n\nProducts used: \nKey Light: Amaran 60x \nFill Light: An old light I had\nRim Light: Godox TL30 8W RGB Light\nBackground Light: Old LED\n\nSoftbox: Aperture Light dome SE\n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-05T10:30:10Z',
#   'Duration': 'PT11M45S',
#   'Views': '27940',
#   'Likes': '1289',
#   'Comments': '144',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': '8QG4uiGMfoQ',
#   'Title': '💡How to setup YouTube Studio lights 🎥',
#   'Tags': ['hobby explorer tamil',
#    'ஒளிப்பதிவு',
#    'சிறந்த ஒளிப்பதிவு',
#    'cinematography',
#    'cinematography tutorial',
#    'cinematography techniques',
#    'cinematography style',
#    'cinematography lighting',
#    'youtube studio lighting',
#    'youtube lighting setup',
#    'lighting for youtube videos',
#    'lighting setup for youtube videos',
#    'youtube studio setup small room',
#    'youtube lighting',
#    'amaran 60x',
#    'godox',
#    'small rig',
#    'amaran 200x',
#    'key light',
#    'fill light',
#    'rim light',
#    'honeycomb',
#    'YouTube studio lighting setup',
#    'budget garage studio'],
#   'Thumbnail': 'https://i.ytimg.com/vi/8QG4uiGMfoQ/default.jpg',
#   'Description': "💡 Poor lighting is worse than having an old camera.\n💡 I was told by many people that I should upgrade my camera.\n💡 But, I am going against the advice and upgrading the lights.\n💡 Fundamentals of lighting:\n💡 Key light: Primary source of light\n💡 Fill light: Secondary source\n💡 Rim light: Used to differentiate the subject from background.\n💡 Learn more about this 3 point lighting system in my newest YouTube video.\n\n❤️ Video made by Hobby & Explorer(Our editor)\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-05T10:30:04Z',
#   'Duration': 'PT30S',
#   'Views': '348965',
#   'Likes': '25028',
#   'Comments': '66',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': '68EkT-gj9oM',
#   'Title': 'Dry Food scene in Germany 🤮🇩🇪🍕',
#   'Tags': ['hobby explorer tamil',
#    'india',
#    'usa',
#    'hobby explorer',
#    'switzerland food',
#    'food in switzerland',
#    'swiss food',
#    'switzerland',
#    'cheap food in switzerland',
#    'best food in zurich',
#    'food',
#    'switzerland food tour',
#    'what food to get in switzerland',
#    'what food to order in switzerland',
#    'swiss food tour',
#    'swiss food video',
#    'switzerland travel',
#    'switzerland traditional food',
#    'top food in switzerland',
#    'veg food in switzerland',
#    'best food in switzerland',
#    'சுவிட்சர்லாந்து',
#    'Bratwurst in Germany',
#    'No fiber',
#    'hobby food vlog'],
#   'Thumbnail': 'https://i.ytimg.com/vi/68EkT-gj9oM/default.jpg',
#   'Description': '🇨🇭🇩🇪🍕 I found most of European countries to have very dry food scene.\nDear Europeans, where are you really getting your fiber?\n😰 Switzerland and Germany are the worst.\n🇮🇳 I couldn’t survive there for 3 days without going to an Indian restaurant.',
#   'Published_Date': '2024-04-04T10:30:03Z',
#   'Duration': 'PT34S',
#   'Views': '982908',
#   'Likes': '62081',
#   'Comments': '212',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'Q4xiHPyNfh8',
#   'Title': '🇨🇭 Switzerland Trains 5000kms track 🚉',
#   'Tags': ['hobby explorer tamil',
#    'switzerland',
#    'switzerland train',
#    'switzerland trains',
#    'swiss trains',
#    'interlaken switzerland',
#    'train spotting in switzerland',
#    'cab ride switzerland',
#    'switzerland travel',
#    'how to switzerland',
#    'swiss train',
#    'trains in switzerland',
#    'train driver view',
#    'switzerland train ride',
#    'switzerland train tour',
#    'சுவிட்சர்லாந்து',
#    'சுவிட்சர்லாந்து சுற்றுலா',
#    'switzerland tourism',
#    'switzerland travel vlog',
#    'switzerland vlog',
#    'travel switzerland',
#    'explore switzerland',
#    'winter in switzerland'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Q4xiHPyNfh8/default.jpg',
#   'Description': "🧀 Switzerland has all kinds of trains.\n🚆 Teethed ones, regular ones, winches, electric... there is about 5000kms worth of track.\n🚞 Switzerland citizens travelled 2500kms in 2019 just by trains! 🚊\n \n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/ @Hobby_Explorer",
#   'Published_Date': '2024-04-03T10:30:16Z',
#   'Duration': 'PT40S',
#   'Views': '930494',
#   'Likes': '60732',
#   'Comments': '436',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'maSDOAiBnGc',
#   'Title': '🤣 ABCD meets EFGH 🙄',
#   'Tags': ['hobby explorer tamil',
#    'hobby explorer',
#    'india usa driving difference',
#    'indian vlogger',
#    'driving in usa',
#    'immigrant life in usa',
#    'immigration',
#    'life in america as an immigrant',
#    'living in usa as an immigrant',
#    'india usa difference',
#    'american born confused desi',
#    'american-born confused desi',
#    'abcd: american-born confused desi',
#    'life in usa as an immigrant',
#    'life as an immigrant in usa',
#    'immigrant',
#    'immigrant in america',
#    'being an immigrant in america',
#    'indian immigrants in usa'],
#   'Thumbnail': 'https://i.ytimg.com/vi/maSDOAiBnGc/default.jpg',
#   'Description': '🚗 Driver side confusion ok. But, EFGH na enna? 🙄',
#   'Published_Date': '2024-04-02T05:17:30Z',
#   'Duration': 'PT53S',
#   'Views': '2328935',
#   'Likes': '129301',
#   'Comments': '402',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'hQnVHDBATRg',
#   'Title': '🚴Bicycle friendly Germany, Netherlands and Europe🌍',
#   'Tags': ['hobby explorer tamil',
#    'usa',
#    'india',
#    'hobby explorer',
#    'மிதிவண்டி',
#    'உலக மிதிவண்டி தினம்',
#    'நவீன மிதிவண்டி',
#    'மிதிவண்டியின் பயன்கள்',
#    'germany',
#    'bicycle',
#    'cycling in germany',
#    'bike in germany',
#    'bicycles in germany',
#    'cycling germany',
#    'foreigners in germany',
#    'bicycle touring in germany',
#    'cycle',
#    'bicycle germany',
#    'amsterdam netherlands',
#    'netherlands',
#    'amsterdam',
#    'amsterdam netherlands 4k',
#    'amsterdam travel',
#    'netherlands amsterdam',
#    'travel amsterdam',
#    'amsterdam city tour'],
#   'Thumbnail': 'https://i.ytimg.com/vi/hQnVHDBATRg/default.jpg',
#   'Description': '🚴I found many countries in Europe to be bicycle friendly. They modified or built the city’s design to give higher priority to pedestrians and bicycles. Their public transport is also letting passengers to carry their bicycles inside the trains.\n\nBiggest benefits:\n1. Reduced smog inside the city. 🚗💨\n2. Less parking problems. 🅿️',
#   'Published_Date': '2024-03-30T10:30:14Z',
#   'Duration': 'PT45S',
#   'Views': '559695',
#   'Likes': '42144',
#   'Comments': '190',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'ceaJtB38yF8',
#   'Title': '🪵 Woodworking for beginners',
#   'Tags': ['hobby explorer tamil',
#    'diy birdhouse',
#    'how to build a birdhouse',
#    'easy birdhouse',
#    'birdhouse diy',
#    'easy birdhouses to build',
#    'birdhouse in your soul',
#    'how to make a birdhouse',
#    'easy birdhouse designs',
#    'diy fence board birdhouse',
#    'build a birdhouse from cedar fence',
#    'barn birdhouse',
#    'mini birdhouse',
#    'பறவை இல்லம்',
#    'redwood fence birdhouse',
#    'DIY பறவை இல்லம்',
#    'எளிதான பறவை இல்லம்',
#    'ஒரு பறவை இல்லத்தை எப்படி உருவாக்குவது',
#    'beginners diy',
#    'temu',
#    'மரவேலை',
#    'மர கலை',
#    'ஜன்னல் மரம்',
#    'மரவேலை கைவினைஞர்கள்'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ceaJtB38yF8/default.jpg',
#   'Description': '🪵🐦 In today’s YouTube video I tried to build a birdhouse from scratch.\n🛠️ I used several new tools and faced a few challenges.\n🪚 🗜️Click the link near description and watch the full video.',
#   'Published_Date': '2024-03-29T05:14:57Z',
#   'Duration': 'PT28S',
#   'Views': '463000',
#   'Likes': '30526',
#   'Comments': '71',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'lQYEUgPWsNQ',
#   'Title': '🐦 How to build a DIY Bird House 🏡',
#   'Tags': ['hobby explorer tamil',
#    'diy birdhouse',
#    'how to build a birdhouse',
#    'easy birdhouse',
#    'birdhouse diy',
#    'easy birdhouses to build',
#    'birdhouse in your soul',
#    'how to make a birdhouse',
#    'easy birdhouse designs',
#    'diy fence board birdhouse',
#    'build a birdhouse from cedar fence',
#    'barn birdhouse',
#    'mini birdhouse',
#    'பறவை இல்லம்',
#    'redwood fence birdhouse',
#    'DIY பறவை இல்லம்',
#    'எளிதான பறவை இல்லம்',
#    'ஒரு பறவை இல்லத்தை எப்படி உருவாக்குவது',
#    'beginners diy',
#    'temu',
#    'மரவேலை',
#    'மர கலை',
#    'ஜன்னல் மரம்',
#    'மரவேலை கைவினைஞர்கள்'],
#   'Thumbnail': 'https://i.ytimg.com/vi/lQYEUgPWsNQ/default.jpg',
#   'Description': "Hobby Difficulty level: Easy \n\n1. Buy a redwood fence picket\n2. 1:42 Take a screenshot of the plan from video. \n3. Follow the plan to make your cuts. \n4. You can cut using a handsaw or any power tool, chopsaw or circular saw (if you are comfortable) . Watch safety videos before using any power tools. \n5. Decide on the hole size based on what bird you would like to attract. (List below)\n6. Verify the cuts by assembling the birdhouse roughly by hand. \n7. Drill pilot holes then drive in the Screws. \n8. Or use nails and wood glue for assembly.  \n\nYou will attract the following birds based on the size of the entrance hole\n* American Kestrel - 3 inches (7.6 cm)\n* Ash-Throated Flycatcher - 1 1/2 inches (3.8 cm)\n* Barn Owl - 6 inches (15.2 cm)\n* Black-Capped Chickadee - 1 1/8 inches (2.85 cm)\n* Carolina Chickadee - 1 1/8 inches (2.85 cm)\n* Carolina Wren - 1 1/2 inches (3.8 cm)\n* Northern Flicker - 2 1/2 inches (6.35 cm)\n* Prothonotary Warbler - 1 1/8 inches (2.85 cm)\n* Purple Martin - 2 1/2 inches (6.35 cm)\n* Tree Swallow - 1 3/8 inches (3.5 cm)\n* Tufted Titmouse - 1 1/4 inches (3.2 cm)\n* Violet-Green Swallow - 1 1/2 inches (3.8 cm)\n* Western Screech-Owl - 3 inches (7.6 cm)\n* White-Breasted Nuthatch - 1 1/4 inches (3.2 cm)\n* Wood Duck - 4 inches (10.2 cm)\n* Downy Woodpecker - 1 1/4 inches (3.2 cm)\n* Eastern Bluebird - 1 1/2 inches (3.8 cm)\n* Eastern Screech-Owl - 3 inches (7.6 cm)\n* House Finch - 2 inches (5.1 cm)\n* House Wren - 1 1/4 inches (3.2 cm)\n\nProducts I used:\nA measuring tape.\nhand saw\nSpeed square\nHammer & Nails\nGlue\nWood clamps\nForstner bit or hole saw\n\nOptional: \nChop Saw or Circular Saw\n\n❤️ Video made by Hobby & Explorer(Our editor)\n\nHobby's Instagram: https://www.instagram.com/hobby_explorer_tamil/\nFacebook: https://www.facebook.com/HobbyExplorer\nEnglish Channel: https://www.youtube.com/@UCrdDQkt15CSD9F59pJo-Kcw",
#   'Published_Date': '2024-03-29T04:28:49Z',
#   'Duration': 'PT11M15S',
#   'Views': '47695',
#   'Likes': '2008',
#   'Comments': '150',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'iqASXwqrTjE',
#   'Title': '🚗 Rental Car in Europe 🌍',
#   'Tags': ['hobby explorer tamil',
#    'usa',
#    'hobby explorer',
#    'india',
#    'rental car in europe',
#    'car rental',
#    'europe',
#    'rent a car',
#    'car rental in europe',
#    'renting a car in europe',
#    'car rental in germany',
#    'europe car rental',
#    'car rental europe',
#    'rental cars',
#    'driving in europe',
#    'driving rental car in europe',
#    'save money on car rental in europe',
#    'car rental tips',
#    'europe trip',
#    'europe travel',
#    'things to do europe trip',
#    'வாடகை Car',
#    'europe travel tips',
#    'europe tourism',
#    'one week in europe',
#    'europe places',
#    'europe tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/iqASXwqrTjE/default.jpg',
#   'Description': '🚗Cost of Rental car in Europe. Surprisingly not that expensive.\n💰 I find rental cars very expensive in US.\n⛽️ In India, how common is it to rent a car thats meant to be driven by yourself?\nHave you rental such car in India?\nWhat was the price?',
#   'Published_Date': '2024-03-28T10:30:15Z',
#   'Duration': 'PT28S',
#   'Views': '1087394',
#   'Likes': '74443',
#   'Comments': '613',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': '6oP0UGl8O44',
#   'Title': 'Petrol Station Confusion in Europe⛽️ 💧🗿',
#   'Tags': ['hobby explorer tamil',
#    'பெட்ரோல் பங்க்',
#    'பெட்ரோல்',
#    'பெட்ரோல் விலை',
#    'petrol',
#    'power petrol',
#    'super petrol',
#    'petrol engine',
#    'super',
#    'germany',
#    'super germany',
#    'ஐரோப்பா சுற்றுப்பயணம்',
#    'europe',
#    'europe travel',
#    'europe tour',
#    'europe tour plan',
#    'europe tourism',
#    'europe tour from india',
#    'where to visit in europe',
#    'europe places',
#    'europe travel video',
#    'travel europe',
#    '14 days europe tour plan',
#    'germany tour',
#    'germany 4k',
#    'germany travel',
#    'top places to visit in germany'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6oP0UGl8O44/default.jpg',
#   'Description': '⛽️ Some countries in Europe call the Petrol as “SUPER” \n💧That is very confusing. I always thought the world either calls it “Petrol” or “GAS” \n🗿But there is one more name called “SUPER” \nIn your town, how do people address petrol? \nIs there one more name I don’t know yet?',
#   'Published_Date': '2024-03-27T10:30:03Z',
#   'Duration': 'PT44S',
#   'Views': '501727',
#   'Likes': '40298',
#   'Comments': '318',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'b3cSdZLAGvM',
#   'Title': '🇱🇺 Luxembourg Honest Library',
#   'Tags': ['hobby explorer tamil',
#    'Honest Library',
#    'hobby explorer',
#    'library',
#    'honest',
#    'best library',
#    'usa',
#    'india',
#    'luxembourg',
#    'europe',
#    'luxembourg country',
#    'luxembourg city',
#    'things to do in luxembourg',
#    'luxembourg 4k',
#    'europe travel',
#    'europe live',
#    'europe 4k',
#    'europe tourism',
#    'europe places',
#    '#europe',
#    'europe explained',
#    'europe 2023',
#    'europa',
#    'europe facts',
#    'travel europe',
#    'places in europe',
#    'top places to visit in europe',
#    '#europe fun facts',
#    'continent of europe',
#    'europe map',
#    'luxembourgvlog',
#    'europetravelvlog',
#    'luxemberg'],
#   'Thumbnail': 'https://i.ytimg.com/vi/b3cSdZLAGvM/default.jpg',
#   'Description': 'Luxembourgians are honest AF. I saw an unlocked tiny library pick up location. Yet, nothing is stolen. So its true. 📚 Readers never steal 📚Stealers never read.',
#   'Published_Date': '2024-03-26T10:30:22Z',
#   'Duration': 'PT31S',
#   'Views': '365717',
#   'Likes': '32333',
#   'Comments': '630',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'h0wyv0eIlWo',
#   'Title': '🇱🇺 Luxembourg Free Schools',
#   'Tags': ['hobby explorer tamil',
#    'இலவச பள்ளி',
#    'ஐரோப்பா',
#    'usa',
#    'india',
#    'luxembourg',
#    'europe',
#    'luxembourg country',
#    'luxembourg city',
#    'things to do in luxembourg',
#    'europe travel',
#    'europe live',
#    'europe 4k',
#    'europe tourism',
#    'europe places',
#    '#europe',
#    'europe explained',
#    'europe 2023',
#    'europe travel guide',
#    'europa',
#    'europe facts',
#    'travel europe',
#    'places in europe',
#    'top places to visit in europe',
#    '#europe fun facts',
#    'continent of europe',
#    'europe map',
#    'luxemberg',
#    'பள்ளி இலவச சேர்க்கை',
#    'இலவச கல்வி',
#    'hobby explorer'],
#   'Thumbnail': 'https://i.ytimg.com/vi/h0wyv0eIlWo/default.jpg',
#   'Description': '🇱🇺 Luxembourgians, is that what they call? Luxembourgians know what they are doing. Free Bus, Free Train, Free Library, Free School. 🎓',
#   'Published_Date': '2024-03-23T05:06:14Z',
#   'Duration': 'PT40S',
#   'Views': '628966',
#   'Likes': '57150',
#   'Comments': '410',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'yHKfOjJDia0',
#   'Title': '🇱🇺 Luxembourg Population 6.5 Lakhs',
#   'Tags': ['hobby explorer tamil',
#    'usa',
#    'india',
#    'luxembourg',
#    'europe',
#    'luxembourg country',
#    'luxembourg city',
#    'things to do in luxembourg',
#    'luxembourg 4k',
#    'europe travel',
#    'europe live',
#    'europe 4k',
#    'europe tourism',
#    'europe places',
#    '#europe',
#    'europe explained',
#    'europe 2023',
#    'europe travel guide',
#    'europa',
#    'europe facts',
#    'travel europe',
#    'places in europe',
#    'top places to visit in europe',
#    'best places to visit in europe',
#    '#europe fun facts',
#    'continent of europe',
#    'europe map',
#    'luxembourgvlog',
#    'europetravelvlog',
#    'luxemberg'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yHKfOjJDia0/default.jpg',
#   'Description': 'I visited my friend in 🇱🇺 Luxembourg. You only need a day to tour the country.',
#   'Published_Date': '2024-03-22T10:30:32Z',
#   'Duration': 'PT37S',
#   'Views': '652856',
#   'Likes': '53494',
#   'Comments': '421',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'T8L0azJeN68',
#   'Title': '🎨 Air Drawing with Vision Pro | Hobby Explorer Tamil',
#   'Tags': ['apple vision pro',
#    'vision pro',
#    'apple vision',
#    'apple vision pro review',
#    'vision',
#    'apple vision pro drawing',
#    'design vision pro drawing',
#    'vision pro review',
#    'vision pro apps',
#    'drawing tutorial',
#    'apple vision pro vs',
#    'apple vision pro apps',
#    'ஆப்பிள் விஷன் ப்ரோ',
#    'விஷன் ப்ரோ',
#    'விஷன் ப்ரோ ஆப்பிள்',
#    'ஆப்பிள் ப்ரோ',
#    'hobby explorer tamil',
#    'india',
#    'usa',
#    'vision pro hands on',
#    'technology',
#    'art and technology',
#    'arts and culture',
#    'technews',
#    'tech',
#    'techie',
#    'tedtalk',
#    'ted talk',
#    'ted talks',
#    'techtips',
#    'high-tech',
#    'techreview'],
#   'Thumbnail': 'https://i.ytimg.com/vi/T8L0azJeN68/default.jpg',
#   'Description': 'Explorers! Today, I am drawing a tree 🌴 using Apple Vision Pro. 🎨\n\nName of the App on Vision Pro: Air Draw \nCost: Free \n\nThere are a few other air drawing apps on vision pro. But I found this to be a decent free version.',
#   'Published_Date': '2024-03-22T10:30:18Z',
#   'Duration': 'PT5M54S',
#   'Views': '48771',
#   'Likes': '1645',
#   'Comments': '156',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'YucviboOGs0',
#   'Title': '🇧🇪 Belgium Street Performance Rules 🎭',
#   'Tags': ['hobby explorer tamil',
#    'india',
#    'usa',
#    'belgium',
#    'belgium travel',
#    'brussels belgium',
#    'belgium 2022',
#    'belgium tour',
#    'belgium video',
#    'belgium house',
#    'europe',
#    'europe travel',
#    'europe tourism',
#    'europe tour plan',
#    'europe places',
#    'europe travel tips',
#    'europe trip',
#    'பெல்ஜியம்',
#    'எக்ஸ்ப்லோர் பெல்ஜியம்',
#    'belgium facts',
#    'belgium country',
#    'belgium tamil',
#    'europe tour',
#    'europe 2023',
#    'street performance',
#    'street performer',
#    'street performers',
#    'street',
#    'performance',
#    'live performance',
#    'best street performer'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YucviboOGs0/default.jpg',
#   'Description': 'Belgium la street performance ku rules laam potu vechirkanga.',
#   'Published_Date': '2024-03-21T10:30:19Z',
#   'Duration': 'PT42S',
#   'Views': '374044',
#   'Likes': '29079',
#   'Comments': '101',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'Ka0nOfSl8gM',
#   'Title': '🇧🇪 Belgium Metro Train 🚂',
#   'Tags': ['hobby explorer tamil',
#    'india',
#    'usa',
#    'belgium',
#    'belgium travel',
#    'brussels belgium',
#    'belgium 2022',
#    'belgium tour',
#    'belgium video',
#    'belgium house',
#    'europe',
#    'europe travel',
#    'europe tourism',
#    'europe tour plan',
#    'europe places',
#    'europe travel tips',
#    'places in europe',
#    'europe trip',
#    'பெல்ஜியம்',
#    'எக்ஸ்ப்லோர் பெல்ஜியம்',
#    'belgium facts',
#    'belgium country',
#    'belgium tamil',
#    'europe tour',
#    'europe 2023',
#    'travel europe',
#    'where to visit in europe',
#    'europe travel video',
#    'top places to visit in europe',
#    'west europe tour'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Ka0nOfSl8gM/default.jpg',
#   'Description': 'Button amukkuna dha Brussels la irukka metro train doors open agum am. 🇧🇪 Belgium Metro Train 🚂',
#   'Published_Date': '2024-03-20T10:30:07Z',
#   'Duration': 'PT29S',
#   'Views': '906847',
#   'Likes': '68165',
#   'Comments': '139',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'nF3RzZtqzOs',
#   'Title': '🇧🇪 Belgium Waffles 🧇',
#   'Tags': ['hobby explorer tamil',
#    'india',
#    'usa',
#    'belgian waffles',
#    'waffles',
#    'belgium waffles',
#    'waffle',
#    'belgian waffle',
#    'belgian liege waffles',
#    'belgium',
#    'waffle iron',
#    'homemade belgian waffles',
#    'belgian waffle (food)',
#    'waffle (dish)',
# ...
#    'surprise',
#    'qatar',
#    'emirates',
#    'diml',
#    'day in my life',
#    'chennai',
#    'trichy',
#    'salem',
#    'hosur',
#    'madurai',
#    'shopping',
#    'park',
#    'kids',
#    'children',
#    'visit',
#    'parents',
#    'nri',
#    'abroad',
#    'onsite',
#    'offsite',
#    'cts',
#    'tcs',
#    'wipro',
#    'home',
#    'house',
#    'tesla car tamil',
#    'tamil shorts',
#    'அமெரிக்கா',
#    'tamil nadu',
#    'ttf vasan',
#    'tesla',
#    'number plate in postbox',
#    'america jail tamil',
#    'jail made number plates',
#    'america vlog',
#    'california tamil vlog',
#    'tamil prison workers in america',
#    'Hobby Explorer Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/jlF_aFj0U1c/default.jpg',
#   'Description': 'அமெரிக்காவில் நம்பர் பிளேட்டுகள் சிறைத் தொழில் ஆணையத்தால் தயாரிக்கப்படுகின்றன.\n\nNumber plates in America are made by Prison Industry Authority.\n\n\n#America\n#AmericaTamil\n#AmericaNRI \n#TamilNRI \n#NRI \n#Immigrant\n#LicensePlates \n#NumberPlates\n#NumberPlateHack\n#TeslaPlates',
#   'Published_Date': '2023-06-18T03:29:42Z',
#   'Duration': 'PT43S',
#   'Views': '375850',
#   'Likes': '30440',
#   'Comments': '90',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'CQHjtZvAjtg',
#   'Title': '📮அமெரிக்கா-ல தபால்-ல தகுடு Shock!',
#   'Tags': ['Tamil',
#    'USA',
#    'usa tamil vlog',
#    'Tamil mom',
#    'nri tamil vlogs',
#    'india travel',
#    'usa to india',
#    'surprise',
#    'qatar',
#    'emirates',
#    'diml',
#    'day in my life',
#    'chennai',
#    'trichy',
#    'salem',
#    'hosur',
#    'madurai',
#    'shopping',
#    'park',
#    'visit',
#    'nri',
#    'abroad',
#    'onsite',
#    'offsite',
#    'cts',
#    'tcs',
#    'wipro',
#    'accenture',
#    'home',
#    'house',
#    'tesla car tamil',
#    'tamil shorts',
#    'அமெரிக்கா',
#    'tamil nadu',
#    'ttf vasan',
#    'tesla',
#    'car number plate tamil',
#    'america steve jobs tamil',
#    'california tamil vlog',
#    'postbox tamil america',
#    'number plate in postbox',
#    '6 months',
#    'no plate',
#    'Hobby Explorer Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/CQHjtZvAjtg/default.jpg',
#   'Description': 'தமிழில்:\n"நம்பர் பிளேட்டுகள் காரின் தோற்றத்தை கெடுக்கும்" - ஸ்டீவ் ஜாப்ஸ் பிரபலமாக கூறினார் 😂\nஅதனால் நம்பர் பிளேட் போடாமல் இருக்க 6 மாதங்களுக்கு ஒருமுறை புதிய கார் வாங்கினார்!\n\nஅமெரிக்காவில், கார் வாங்கும் போது உடனே நம்பர் பிளேட் கொடுக்க மாட்டார்கள்.\nநம்பர் பிளேட்டுகள் ஒரு மாதம் கழித்து வீட்டிற்கு வந்து சேரும்.\nஅதை நம் வீட்டில் நாமே நிறுவ வேண்டும்.\nசில ஆண்டுகளுக்கு முன்பு, சட்டம் இருந்தது - உங்கள் அசல் தட்டுகளைப் பெறும் வரை உங்கள் காரை எண் பலகைகள் இல்லாமல் ஓட்டலாம்.\n\nஆனால், ஸ்டீவ் ஜாப்ஸின் பிரபலமான செயலால் கலிபோர்னியா அதன் சட்டத்தை மாற்றியுள்ளது.\n\nIn English:\n"Number plates ruin the look of the car" - Steve Jobs famously said 😂\nSo he bought one new car every 6 months to avoid putting any number plates on it. \n\nIn America, they don\'t immediately give the car number plates when you buy. \nNumber plates arrive at home more than a month later. \nWe have to install it ourselves at our home. \nA few years ago, the law was that - you can drive your car around plateless until you get your original plates. \n\nBut, California has changed its law ever since the popular act by steve jobs.',
#   'Published_Date': '2023-06-18T02:46:37Z',
#   'Duration': 'PT38S',
#   'Views': '353799',
#   'Likes': '30506',
#   'Comments': '68',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'PWasQr-aPAU',
#   'Title': '🏠  America-ல என் வீட்டின் முன் பலகை வைத்திருந்தார்கள் - Real Estate Shock!',
#   'Tags': ['Tamil',
#    'USA',
#    'energy efficient home america',
#    'usa tamil vlog',
#    'Tamil mom',
#    'nri tamil vlogs',
#    'india travel',
#    'usa to india',
#    'surprise',
#    'qatar',
#    'emirates',
#    'diml',
#    'day in my life',
#    'chennai',
#    'trichy',
#    'salem',
#    'hosur',
#    'madurai',
#    'shopping',
#    'park',
#    'kids',
#    'children',
#    'visit',
#    'parents',
#    'nri',
#    'abroad',
#    'onsite',
#    'cts',
#    'tcs',
#    'wipro',
#    'accenture',
#    'home',
#    'house',
#    'tesla car tamil',
#    'tamil shorts',
#    'அமெரிக்கா',
#    'tamil nadu',
#    'ttf vasan',
#    'america real estate in tamil',
#    'home selling in america',
#    'selling agent',
#    'real estate tamil',
#    'advertisement board',
#    'Hobby Explorer Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/PWasQr-aPAU/default.jpg',
#   'Description': 'என் வீட்டின் முன் ஒரு ரியல் எஸ்டேட் சைன் போர்டு இருந்தது.\nஅது என்னவென்று தெரிந்துகொள்ள சென்றேன்.\nவீடுகளுக்கு முன் யார் வேண்டுமானாலும் சட்டக விளம்பரப் பலகைகளை அமைக்கலாம் என்று சட்டம் உள்ளது போல் தெரிகிறது.\nஆனால், அன்று மாலை 5 மணிக்கு மேல் அதை அகற்ற வேண்டும்.\nரியல் எஸ்டேட் விற்பனையின் நோக்கத்திற்காக நீங்கள் தற்காலிக ஏ பிரேம் விளம்பரங்களை அமைக்க அதிகபட்சம் 14 நாள் கால அவகாசம் உள்ளது.\nநான் சந்தித்த விற்பனை முகவர் மிகவும் கண்ணியமானவர்.\n\nபோர்டின் நோக்கம் மற்றும் அமெரிக்காவை விற்பனை செய்யும் வீடு எவ்வாறு செயல்படுகிறது என்பதை விளக்கவே இந்த வீடியோவை உருவாக்கினேன்.\n\nThere was a real estate sign board in front of my house. \nI went on to find out what that was. \nLooks like there is a law which states, anyone can setup A Frame advertisement boards in front of houses. \nBut, they have to remove it after 5pm on that day. \nThere is a maximum of 14 day period where you can setup temporary A Frame advertisements for the purpose of real estate selling. \nThe selling agent I met was very courteous. \n\nI made this video to explain the purpose of the board and how house selling America works.',
#   'Published_Date': '2023-06-17T22:55:29Z',
#   'Duration': 'PT43S',
#   'Views': '1836731',
#   'Likes': '102443',
#   'Comments': '167',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'nMv9AxN4a8Q',
#   'Title': '⚡அமெரிக்காவில் Current Bill  ₹34,000 - Shock!',
#   'Tags': ['Tamil',
#    'USA',
#    'energy efficient home america',
#    'usa tamil vlog',
#    'Tamil mom',
#    'nri tamil vlogs',
#    'india travel',
#    'usa to india',
#    'surprise',
#    'qatar',
#    'emirates',
#    'diml',
#    'day in my life',
#    'chennai',
#    'trichy',
#    'salem',
#    'hosur',
#    'madurai',
#    'shopping',
#    'park',
#    'visit',
#    'parents',
#    'nri',
#    'abroad',
#    'onsite',
#    'offsite',
#    'cts',
#    'tcs',
#    'wipro',
#    'accenture',
#    'home',
#    'house',
#    'library book return tamil',
#    'tesla car tamil',
#    'usa library tour',
#    'america library epdi irkum',
#    'tamil shorts',
#    'library books in america',
#    'அமெரிக்கா',
#    'நூலகம்',
#    'நூல்',
#    'அமெரிக்க சுற்றுப்பயணம்',
#    'Hobby Explorer Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/nMv9AxN4a8Q/default.jpg',
#   'Description': "Na Apdey shock aiten (நான் அதிர்ச்சியடைந்தேன்) \n\nஆங்கிலத்தில்:\nI recently got an electricity bill of 420 dollars for my home in America. \n\nWhere I live (San Francisco, California) Everyone here is either a Software Engineer or Engineering Manager. \nSo naturally all of us are very climate conscious. \nMany of us have transitioned to fully sustainable energy sources like Wind and Solar. \n\nIn the bay area, there is an option to choose a fully sustainable method of energy. So I did make the choice, so all my energy usage in my home is coming from either wind or solar farms far away from my home. \n\nBut since the grid operator is still old and their grid is failing. They need money to upkeep the infrastructure. So, they jacked up the prices for all the other folks like me who don't have their own solar panels installed at home. \n\nThis is the reason why my electricity bill keeps climbing. \n\nLast year I got a bill of $1000 Which is ₹81,000\n\nI took active measures to reduce the bill like: \nUsing Heat-pump based heaters and ACs. \nI schedule to charge my Tesla after midnight. Because that's when the electricity is off-peak charge. \n\nEven with all the effort. My bill is $421. \n\nI am going to make my house more efficient by \n1. Improving the insulation around the walls of my home.\n2. Adding Radiant barrier under the roof(To reflect away sun's heat)\n3. Adding Energy efficient double-pane windows. \n\nThese measures will further reduce my bill. \n\nThese are called passive energy efficiency improvements. \n\nதமிழில்:\nசமீபத்தில் அமெரிக்காவில் உள்ள எனது வீட்டிற்கு 420 டாலர் மின்சாரக் கட்டணம் வந்துள்ளது.\n\nநான் வசிக்கும் இடம் (சான் ஃபிரான்சிஸ்கோ, கலிபோர்னியா) இங்கு உள்ள அனைவரும் மென்பொருள் பொறியாளர் அல்லது பொறியியல் மேலாளர்.\nஎனவே இயற்கையாகவே நாம் அனைவரும் மிகவும் காலநிலை உணர்வுடன் இருக்கிறோம்.\nநம்மில் பலர் காற்று மற்றும் சூரிய சக்தி போன்ற முழுமையான நிலையான ஆற்றல் ஆதாரங்களுக்கு மாறியுள்ளோம்.\n\nவிரிகுடா பகுதியில், ஒரு முழுமையான நிலையான ஆற்றல் முறையைத் தேர்ந்தெடுக்க ஒரு விருப்பம் உள்ளது. எனவே நான் தேர்வு செய்தேன், எனவே எனது வீட்டில் எனது ஆற்றல் பயன்பாடு அனைத்தும் எனது வீட்டிலிருந்து வெகு தொலைவில் உள்ள காற்றாலை அல்லது சூரியப் பண்ணைகளில் இருந்து வருகிறது.\n\nஆனால் கிரிட் ஆபரேட்டர் இன்னும் பழையதாக இருப்பதால், அவர்களின் கட்டம் தோல்வியடைந்து வருகிறது. உள்கட்டமைப்பைப் பராமரிக்க அவர்களுக்குப் பணம் தேவைப்படுகிறது. எனவே, வீட்டில் சொந்தமாக சோலார் பேனல்கள் நிறுவப்படாத என்னைப் போன்ற மற்ற அனைவருக்கும் அவர்கள் விலையை உயர்த்தினார்கள்.\n\nஇதுவே எனது மின்கட்டணம் ஏறிக்கொண்டே இருப்பதற்கு காரணம்.\n\nகடந்த ஆண்டு எனக்கு $1000 பில் கிடைத்தது, அதாவது ₹81,000\n\nபில்லைக் குறைக்க நான் தீவிர நடவடிக்கைகளை எடுத்தேன்:\nஹீட்-பம்ப் அடிப்படையிலான ஹீட்டர்கள் மற்றும் ஏசிகளைப் பயன்படுத்துதல்.\nநள்ளிரவுக்குப் பிறகு எனது டெஸ்லாவை சார்ஜ் செய்ய திட்டமிட்டுள்ளேன். ஏனென்றால் அப்போதுதான் மின்சாரம் ஆஃப் பீக் சார்ஜ்.\n\nஎல்லா முயற்சியுடனும் கூட. எனது பில் $421.\n\nநான் என் வீட்டை இன்னும் திறமையாக மாற்றப் போகிறேன்\n1. எனது வீட்டின் சுவர்களைச் சுற்றியுள்ள காப்புகளை மேம்படுத்துதல்.\n2. கூரையின் கீழ் கதிரியக்கத் தடையைச் சேர்ப்பது (சூரியனின் வெப்பத்தைப் பிரதிபலிக்க)\n3. ஆற்றல் திறன் கொண்ட இரட்டைப் பலக ஜன்னல்களைச் சேர்த்தல்.\n\nஇந்த நடவடிக்கைகள் எனது கட்டணத்தை மேலும் குறைக்கும்.\n\nஇவை செயலற்ற ஆற்றல் திறன் மேம்பாடுகள் என்று அழைக்கப்படுகின்றன.",
#   'Published_Date': '2023-06-17T01:07:35Z',
#   'Duration': 'PT55S',
#   'Views': '883768',
#   'Likes': '71665',
#   'Comments': '293',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'QsbaZjhAyAQ',
#   'Title': '📚 America-வில் Library Book Return Just miss la செஞ்சேன்',
#   'Tags': ['Tamil',
#    'Business',
#    'USA',
#    'Startup',
#    'usa tamil vlog',
#    'tamil usa channel',
#    'Tamil mom',
#    'nri tamil vlogs',
#    'india travel',
#    'usa to india',
#    'surprise',
#    'qatar',
#    'emirates',
#    'diml',
#    'day in my life',
#    'chennai',
#    'trichy',
#    'salem',
#    'hosur',
#    'madurai',
#    'shopping',
#    'park',
#    'kids',
#    'children',
#    'visit',
#    'nri',
#    'abroad',
#    'onsite',
#    'cts',
#    'tcs',
#    'wipro',
#    'accenture',
#    'home',
#    'house',
#    'library book return tamil',
#    'tesla car tamil',
#    'usa library tour',
#    'america library epdi irkum',
#    'tamil shorts',
#    'library books in america',
#    'அமெரிக்கா',
#    'நூலகம்',
#    'நூல்',
#    'அமெரிக்க சுற்றுப்பயணம்',
#    'Hobby Explorer Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/QsbaZjhAyAQ/default.jpg',
#   'Description': 'ஆங்கிலத்தில்:\nI almost forgot to return my library book in California, America, USA. Fine for not returning library books by the deadline is 25 cents per day. \nThankfully I remembered before the deadline. \ncome along with me  to return this book in the library today at South San Francisco Public Library. \n\nPublic Library System in Bay area is fantastic. \nYou can checkout any book from any library and all the libraries in Bay Area are inter-connected. It is a system called "peninsula library system" \n\nYou can request book from one place and it will be automatically moved from origin location to your preferred location nearby your home. \n\nYou can then drive up to the nearest library and pick up your book. \n\nI read hundreds of books for free by using the Free Library system. Library is open 7 days a week! Except public holidays. \n\nWIFI is also free inside and outside the library. Even if it rains. You can take shelter outside library and still use the free WIFI. \n\nTax dollars are properly used here!\n\nதமிழில்: \nகலிபோர்னியாவில் உள்ள எனது நூலகப் புத்தகத்தைத் திருப்பித் தர மறந்துவிட்டேன். காலக்கெடுவிற்குள் நூலகப் புத்தகங்களைத் திருப்பித் தரவில்லை என்றால் ஒரு நாளைக்கு 25 காசுகள் அபராதம்.\nஅதிர்ஷ்டவசமாக நான் காலக்கெடுவுக்கு முன்பே நினைவில் வைத்தேன்.\nஇன்று சவுத் சான் பிரான்சிஸ்கோ பொது நூலகத்தில் உள்ள நூலகத்தில் இந்தப் புத்தகத்தைத் திருப்பித் தர என்னுடன் வாருங்கள். (Vlog with me)\n\nவளைகுடா பகுதியில் உள்ள பொது நூலக அமைப்பு அருமையாக உள்ளது.\nநீங்கள் எந்த நூலகத்திலிருந்தும் எந்த புத்தகத்தையும் செக்அவுட் செய்யலாம் மற்றும் பே ஏரியாவில் உள்ள அனைத்து நூலகங்களும் ஒன்றோடொன்று இணைக்கப்பட்டுள்ளன. இது "தீபகற்ப நூலக அமைப்பு" peninsula library system எனப்படும் அமைப்பு.\n\nநீங்கள் ஒரு இடத்திலிருந்து புத்தகத்தைக் கோரலாம், மேலும் அது தானாகவே உங்கள் வீட்டிற்கு அருகிலுள்ள உங்கள் விருப்பமான இடத்திற்கு, அசல் இடத்திலிருந்து நகர்த்தப்படும்.\n\nஅதற்கு பிறகு\nநீங்கள் அருகிலுள்ள நூலகத்திற்குச் சென்று உங்கள் புத்தகத்தை எடுத்துக் கொள்ளலாம்.\n\nஇலவச நூலக அமைப்பைப் பயன்படுத்தி நூற்றுக்கணக்கான புத்தகங்களை இலவசமாகப் படித்தேன். நூலகம் வாரத்தில் 7 நாட்களும் திறந்திருக்கும்! பொது விடுமுறை நாட்களைத் தவிர.\n\nநூலகத்திற்கு உள்ளேயும் வெளியேயும் வைஃபை WIFI இலவசம். மழை பெய்தாலும் சரி. நீங்கள் லைப்ரரிக்கு வெளியே இலவச வைஃபை பயன்படுத்தலாம்.\n\nவரி டாலர்கள் இங்கே சரியாகப் பயன்படுத்தப்படுகின்றன!',
#   'Published_Date': '2023-06-16T04:15:18Z',
#   'Duration': 'PT39S',
#   'Views': '968372',
#   'Likes': '71506',
#   'Comments': '132',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Hobby Explorer Tamil',
#   'Channel_Id': 'UCYqXh1HzJSYYYmbaoK4veDw',
#   'Video_Id': 'k9b7vB8Bxrk',
#   'Title': '😘 America Library-ல் 📀 கன்னத்தில் முத்தமிட்டால் DVD irku!',
#   'Tags': ['Tamil',
#    'USA',
#    'free 3d printing in america',
#    'free 3d printing in san francisco library',
#    'books',
#    'gaming cds',
#    'usa tamil vlog',
#    'tamil usa channel',
#    'Tamil mom',
#    'nri tamil vlogs',
#    'india travel',
#    'usa to india',
#    'surprise',
#    'qatar',
#    'emirates',
#    'day in my life',
#    'chennai',
#    'trichy',
#    'salem',
#    'hosur',
#    'madurai',
#    'nri',
#    'abroad',
#    'onsite',
#    'cts',
#    'tcs',
#    'wipro',
#    'accenture',
#    'library book return tamil',
#    'usa library tour',
#    'america library epdi irkum',
#    'tamil shorts',
#    'library books in america',
#    'அமெரிக்கா',
#    'அமெரிக்க சுற்றுப்பயணம்',
#    'Hobby Explorer Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/k9b7vB8Bxrk/default.jpg',
#   'Description': 'America Library-ல் 😘 கன்னத்தில் முத்தமிட்டால் DVD 📀 irku!\n\nஆங்கிலத்தில்:\nI found kannathil muthamittal dvd in my area(San Francisco, California) Library. \n\nYes! Our Area library not only carries books, They also have movie DVDs, Gaming CDs. \n\nIn fact, there is also 3D printing machine. Anyone can reserve the 3D printing machine for 1 day and print anything they want for free. \n\nI reserved the 3D printing machine for one full day and printed a small photo frame. First print, it came out very well. \n\n\nதமிழில்:\nஎனது பகுதியில் (சான் பிரான்சிஸ்கோ, கலிபோர்னியா) நூலகத்தில் கன்னத்தில் முத்தமிட்டல் டிவிடியைக் கண்டேன்.\n\nஆம்! எங்கள் ஏரியா லைப்ரரியில் புத்தகங்கள் மட்டுமின்றி, திரைப்பட டிவிடிகள், கேமிங் சிடிக்களும் உள்ளன.\n\nஉண்மையில், 3D அச்சு இயந்திரமும் உள்ளது. எவரும் 3டி பிரிண்டிங் இயந்திரத்தை 1 நாளுக்கு முன்பதிவு செய்து, தாங்கள் விரும்பும் எதையும் இலவசமாக அச்சிடலாம்.\n\n3டி பிரிண்டிங் மெஷினை ஒரு நாள் முழுவதும் ரிசர்வ் செய்து சிறிய போட்டோ ஃபிரேமை அச்சிட்டேன். முதல் அச்சு, நன்றாக வந்தது.',
#   'Published_Date': '2023-06-16T03:41:39Z',
#   'Duration': 'PT59S',
#   'Views': '1920640',
#   'Likes': '151950',
#   'Comments': '317',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
len(video_details)
# Out:
# 296

# %% [markdown]
# #getting comment information from videos

# %%
#getting comment information from videos
def get_comment_info(videos_ids_all): #videos_ids_all has video_id dat from that only we are taking comments details so we are using it as arguments
        comment_data=[]
        try:
                for video_id in videos_ids_all:
                        comment_request=youtube.commentThreads().list(
                                part="snippet",
                                videoId=video_id,
                                maxResults=50
                                
                        )
                        response=comment_request.execute()


                        for item in response["items"]:
                                comment=dict(comment_id = item['snippet']['topLevelComment']['id'],
                                        video_Id = item['snippet']['topLevelComment']['snippet']['videoId'],
                                        comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay'],
                                        Author_name = item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                        comment_published = item['snippet']['topLevelComment']['snippet']['publishedAt'])
                        
                                comment_data.append(comment)
                        
        except:
                pass
        return comment_data

# %%
Comment_details1 = get_comment_info(videos_ids_all)

# %%
if Comment_details1 is not None:
    Comm = len(Comment_details1)
else:
    print("comment is null")
# Out:
# comment is null

# %% [markdown]
# #Playlist details

# %%
def get_playlist_details(channel_id):
        next_page_token=None
        playlist_data=[]
        while True:
                playlistrequest=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                playlistresponse=playlistrequest.execute()

                for item in playlistresponse['items']:
                        data=dict(Playlist_Id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_Count=item['contentDetails']['itemCount'])
                        playlist_data.append(data)

                next_page_token=playlistresponse.get('nextPageToken')
                if next_page_token is None:
                        break
        return playlist_data

# %%
playlist = get_playlist_details(channel_id)

# %%
len(playlist)
# Out:
# 17

# %% [markdown]
# #MONOGODB

# %%
# creating database using pymongo
client = pymongo.MongoClient("mongodb+srv://yokesh:root1234@yokesh.x3ibwxy.mongodb.net/")
db=client["YOUTUBE_DATA_NEW"] # created YOUTUBE_DATA in mongodb.

# %%
def Allchannel_details(channel_id):
    get_channels = get_channel(channel_id)
    videoID = get_videoIDs(channel_id)
    videodetails = get_video_details(videoID) # we are giving videoid as input to get video details 
    comment_id = get_comment_info(videoID) # we are giving videoid as input to get comment info
    playlistdetails = get_playlist_details(channel_id)
    
    collect=db["AllChannel_Details"]
    collect.insert_one({"Channel":get_channels,"Playlist":playlistdetails,"Comment":comment_id,"VideoDetails":videodetails}) #inserting these data's in monogodb as json data (":" is said to scope) 

    return "Uploaded Successfully"

# %%
ins = Allchannel_details(channel_id)

# %% [markdown]
# #CHANNEL_TABLE

# %%
#Table create
def channel_table(single_channel_name):
    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="Root@123",
                            database="youtube",
                            port="5433")
    cursor = mydb.cursor()


    create_query = '''create table if not exists channel(channel_name varchar(255),
                                                            channel_id varchar(255) primary key,
                                                            Subcriber_count bigint,
                                                            Channel_views bigint,
                                                            Total_Videos int,
                                                            Channel_description text,
                                                            Playlist_id varchar(100))'''
    
    cursor.execute(create_query) #EXECUTE command prepares and runs commands dynamically
    mydb.commit() 

    #COMMIT :
    #PostgreSQL COMMIT command is used to save changes and reflect it database whenever we display the required data. 
    #For suppose we updated data in the database but we didn’t give COMMIT then the changes are not reflected in the database


    #extracted channel data from mongodb and changed the data into dataframe(table)
    single_channel_detail=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for chan_data in collect.find({"Channel.channel_name": single_channel_name},{"_id":0}):
            single_channel_detail.append(chan_data["Channel"])
    df_single_channel_detail=pd.DataFrame(single_channel_detail)


    #extracted channeldata from mongodb inserted in prostgresql
    for index,rows in df_single_channel_detail.iterrows():
        insert_query = '''insert into channel(channel_name ,
                                                channel_id ,
                                                Subcriber_count ,
                                                Channel_views ,
                                                Total_Videos ,
                                                Channel_description ,
                                                Playlist_id )
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s)'''
        
        values =(rows["channel_name"],
                rows["channel_id"],
                rows["Subcriber_count"],
                rows["Channel_views"],
                rows["Total_Videos"],
                rows["Channel_description"],
                rows["Playlist_id"])
        
        try:    
                cursor.execute(insert_query,values) #execute the data of insert_queries and values
                mydb.commit()
        except:
              
              new= f"You provided channel {single_channel_name} Already exists in Table"
              return new

# %%
channel_table("Cherry Vlogs")

# %% [markdown]
# #PLAYLIST_TABLE

# %%
def Playlists_table(single_channel_name):
    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="Root@123",
                            database="youtube",
                            port="5433")
    cursor = mydb.cursor()

    create_query = '''create table if not exists Playlists( Playlist_Id varchar(255) primary key,
                                                            Channel_Id varchar(255),
                                                            Channel_Name varchar(255)
                                                            )'''

    cursor.execute(create_query) #EXECUTE command prepares and runs commands dynamically
    mydb.commit() 

    #extracted playlistdata from mongodb inserted in prostgresql
     #extracted channel data from mongodb and changed the data into dataframe(table)
    single_playlist_detail=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for play_data in collect.find({"Channel.channel_name": single_channel_name},{"_id":0}):
            single_playlist_detail.append(play_data["Playlist"])

    df_single_playlist_detail = pd.DataFrame(single_playlist_detail[0]) #while giving [0] the data columns will become title of the tables and the rows will become values

    
    for index,rows in df_single_playlist_detail.iterrows():
        insert_query = '''insert into Playlists(Playlist_Id,
                                                Channel_Id,
                                                Channel_Name)
                                                
                                                values(%s,%s,%s)'''
        
        values =(rows["Playlist_Id"],
                rows["Channel_Id"],
                rows["Channel_Name"],
                )
        
        
        cursor.execute(insert_query,values) #execute the data of insert_queries and values
        mydb.commit()

# %% [markdown]
# #VIDEO_TABLE

# %%
#Table video 
def video_table(single_channel_name):
    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="Root@123",
                            database="youtube",
                            port="5433")
    cursor = mydb.cursor()

    drop_query = '''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()


    
    create_query ='''create table if not exists videos(Channel_Name varchar(100),
                                                Channel_Id varchar(100),
                                                Video_Id varchar(30) primary key,
                                                Title varchar(150),
                                                Tags text,
                                                Thumbnail varchar(200),
                                                Description text,
                                                Published_Date timestamp,
                                                Duration interval,
                                                Views bigint,
                                                Likes bigint,
                                                Comments int,
                                                Favorite_Count int,
                                                Definition varchar(10),
                                                Caption_Status varchar(50)
                                                            )'''
    
    cursor.execute(create_query) #EXECUTE command prepares and runs commands dynamically
    mydb.commit() 

    #COMMIT :
    #PostgreSQL COMMIT command is used to save changes and reflect it database whenever we display the required data. 
    #For suppose we updated data in the database but we didn’t give COMMIT then the changes are not reflected in the database

 

    #extracted video data from mongodb and changed the data into dataframe(table)
    single_video_detail=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for play_data in collect.find({"Channel.channel_name": single_channel_name},{"_id":0}):
            single_video_detail.append(play_data["VideoDetails"])

    df_single_video_detail = pd.DataFrame(single_video_detail[0]) #while giving [0] the data columns will become title of the tables and the rows will become values




    for index,row in df_single_video_detail.iterrows():
            insert_query='''insert into videos(Channel_Name,
                                                    Channel_Id,
                                                    Video_Id,
                                                    Title,
                                                    Tags,
                                                    Thumbnail,
                                                    Description,
                                                    Published_Date,
                                                    Duration,
                                                    Views,
                                                    Likes,
                                                    Comments,
                                                    Favorite_Count,
                                                    Definition,
                                                    Caption_Status
                                                )
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        

            values=(row['Channel_Name'],
                    row['Channel_Id'],
                    row['Video_Id'],
                    row['Title'],
                    row['Tags'],
                    row['Thumbnail'],
                    row['Description'],
                    row['Published_Date'],
                    row['Duration'],
                    row['Views'],
                    row['Likes'],
                    row['Comments'],
                    row['Favorite_Count'],
                    row['Definition'],
                    row['Caption_Status']
                    )

            
            cursor.execute(insert_query,values)
            mydb.commit()

# %% [markdown]
# Comment _ table

# %%
#Table video 
def comment_table(single_channel_name):
    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="Root@123",
                            database="youtube",
                            port="5433")
    cursor = mydb.cursor()

    create_query ='''create table if not exists comments(comment_id varchar(100) primary key,
                                                video_Id varchar(100),
                                                comment_text text,
                                                Author_name varchar(150),
                                                comment_published timestamp
                                                            )'''
    
    cursor.execute(create_query) #EXECUTE command prepares and runs commands dynamically
    mydb.commit() 

    #COMMIT :
    #PostgreSQL COMMIT command is used to save changes and reflect it database whenever we display the required data. 
    #For suppose we updated data in the database but we didn’t give COMMIT then the changes are not reflected in the database



    #extracted video data from mongodb and changed the data into dataframe(table)
    single_comment_detail=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for play_data in collect.find({"Channel.channel_name": single_channel_name},{"_id":0}):
            single_comment_detail.append(play_data["Comment"])

    df_single_comment_detail = pd.DataFrame(single_comment_detail[0]) #while giving [0] the data columns will become title of the tables and the rows will become values

    for index,row in df_single_comment_detail.iterrows():
            insert_query='''insert into comments(comment_id,
                                                    video_Id,
                                                    comment_text,
                                                    Author_name,
                                                    comment_published
                                                )    
                                                values(%s,%s,%s,%s,%s)'''
        

            values=(row['comment_id'],
                    row['video_Id'],
                    row['comment_text'],
                    row['Author_name'],
                    row['comment_published'],
                    
                    )

            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def Sql_Tables(Single_channel):
    channel_table(Single_channel),
    Playlists_table(Single_channel),
    video_table(Single_channel),
    comment_table(Single_channel)

    return "Tables are created successfully"

# %%
tables = Sql_Tables()

# %%
def show_channelDetails():
    Ch_list=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for chan_data in collect.find({},{"_id":0,"Channel":1}):
        Ch_list.append(chan_data["Channel"])
    df=st.dataframe(Ch_list)

    return df

# %%
chann = show_channelDetails()

# %%
chann
# Out:
# DeltaGenerator()

# %%
def show_playlistDetails():        
    pl_list=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for play_data in collect.find({},{"_id":0,"Playlist":1}):
        for i in range(len(play_data["Playlist"])):
            pl_list.append(play_data["Playlist"][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videoDetails():        
    Vid_list=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for Vid_data in collect.find({},{"_id":0,"VideoDetails":1}):
        for i in range(len(Vid_data["VideoDetails"])):
            Vid_list.append(Vid_data["VideoDetails"][i])
    df2=st.dataframe(Vid_list)

    return df2

# %%
def show_commentDetails():    
    com_list=[]
    db=client["YOUTUBE_DATA_NEW"]
    coll1=db["AllChannel_Details"]
    for com_data in coll1.find({},{"_id":0,"Comment":1}):
        if com_data["Comment"] is not None:
            for i in range(len(com_data["Comment"])):
                com_list.append(com_data["Comment"][i])
    df3=st.dataframe(com_list)

    return df3

# %%
comme = show_commentDetails()

# %%
com = show_commentDetails()

# %%
#steamlit - UI 

with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("Skills")
    st.caption("Python scripting")
    st.caption("Data collection")
    st.caption("MONGODB")
    st.caption("Data integration")
    st.caption("Data management using mongodb and sql")

channel_id = st.text_input("Enter the Channel Id")

if st.button("Collect and store data"): #creating button youtube->mongodb data is collected to avoid duplicates in mongodb we are using button
    chan_ids=[]
    db=client["YOUTUBE_DATA_NEW"]
    collect=db["AllChannel_Details"]
    for chan_data in collect.find({},{"_id":0,"Channel":1}):
        chan_ids.append(chan_data["Channel"]["channel_id"])

    if channel_id in chan_ids:
        st.success("Channel details of the given Channel Id is already created")
    else:
        insert=Allchannel_details(channel_id)
        st.success(insert)
# Out:
# 2024-04-14 10:53:10.238
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/yokesh/Vscode/.venv/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %% [markdown]
# #SQL CONNECTION

# %%
#creating select box to select the channels and after selecting the channel get moves to sql.
channel_lists=[]
db=client["YOUTUBE_DATA_NEW"]
coll1=db["AllChannel_Details"]
for chan in coll1.find({},{"_id":0,"Channel":1}):
        channel_lists.append(chan["Channel"]["channel_name"])

uniqueChannels = st.selectbox("Select the channels",channel_lists)
# Out:
# 2024-04-18 00:10:57.217
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/yokesh/Vscode/.venv/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
if st.button("Move to SQL"):
    Table = Sql_Tables(uniqueChannels) #here we are giving arguments as uniquechannels because only the particular channel only loaded in sql.
    st.success(Table)

show_table=st.radio("SELECT THE TABLE TO BE VIEWED",("CHANNEL","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table == "CHANNEL":
    show_channelDetails()
elif show_table == "PLAYLISTS":
    show_playlistDetails()
elif show_table == "VIDEOS":
    show_videoDetails()
elif show_table == "COMMENTS":
    show_commentDetails()

# %%
#connecting database and for each question we provided answer
mydb = psycopg2.connect(host="localhost",
                        user="postgres",
                        password="Root@123",
                        database="youtube",
                        port="5433")
cursor = mydb.cursor()

Questions = st.selectbox("Select your Question",("1.All the videos and their corresponding channels",
                                                 "2.channels have the most number of videos and count",
                                                 "3.Top 10 most viewed videos",
                                                 "4.comments in each videos",
                                                 "5.Videos with higest likes",
                                                 "6.likes of all videos",
                                                 "7.views of each channel",
                                                 "8.videos published in the year of 2022",
                                                 "9.average duration of all videos in each channel",
                                                 "10.videos with highest number of comments"
                                                 ))
#The execute() method is used to execute the SELECT query.
#The fetchall() method retrieves all the rows returned by the query and stores them in the rows variable.
if Questions=="1.All the videos and their corresponding channels":
     query1='''Select title as videos,channel_name as channelname from videos'''
     cursor.execute(query1)
     mydb.commit()
     t1=cursor.fetchall()
     df=pd.DataFrame(t1,columns=["video title","channel name"])
     st.write(df)

elif Questions=="2.channels have the most number of videos and count":
     query2='''select channel_name,total_videos as No_of_videos from channel order by total_videos desc'''
     cursor.execute(query2)
     mydb.commit()
     t2=cursor.fetchall()
     df1=pd.DataFrame(t2,columns=["channel_name","No of videos"])
     st.write(df1)

elif Questions=="3.Top 10 most viewed videos":
     query3='''select channel_name,title as Title,views as Views from videos order by views desc limit 10'''
     cursor.execute(query3)
     mydb.commit()
     t3=cursor.fetchall()
     df2=pd.DataFrame(t3,columns=["channel_name","Title","Top 10 Views"])
     st.write(df2)

elif Questions =="4.comments in each videos":
     query4='''select title as video_title,comments from videos where comments is not null'''
     cursor.execute(query4)
     mydb.commit()
     t4=cursor.fetchall()
     df3=pd.DataFrame(t4,columns=["Video_Title","Comments"])
     st.write(df3)
    
elif Questions=="5.Videos with highest likes":
     query5='''select channel_name,title as Video_title,likes as video_likes from videos where likes is not null order by likes desc'''
     cursor.execute(query5)
     mydb.commit()
     t5=cursor.fetchall()
     df4=pd.DataFrame(t5,columns=["channel_name","Video_Title","Video_likes"])
     st.write(df4)

elif Questions=="6.likes of all videos":
     query6='''select title as Video_title,likes as video_likes from videos'''
     cursor.execute(query6)
     mydb.commit()
     t6=cursor.fetchall()
     df5=pd.DataFrame(t6,columns=["Video_Title","Video_likes"])
     st.write(df5)

elif Questions=="7.views of each channel":
     query7='''select channel_name,channel_views from channel'''
     cursor.execute(query7)
     mydb.commit()
     t7=cursor.fetchall()
     df6=pd.DataFrame(t7,columns=["channel_name","channel_views"])
     st.write(df6)

elif Questions=="8.videos published in the year of 2022":
     query8='''select channel_name,title as Channel_Title,published_date from videos where extract(year from published_date)=2022'''
     cursor.execute(query8)
     mydb.commit()
     t8=cursor.fetchall()
     df7=pd.DataFrame(t8,columns=["channel_name","Channel_Title","published_date"])
     st.write(df7)

elif Questions=="9.average duration of all videos in each channel":
     query9='''select channel_name as channelName,AVG(duration) as Avergaeduration from videos group by channel_name'''
     cursor.execute(query9)
     mydb.commit()
     t9=cursor.fetchall()
     df8=pd.DataFrame(t9,columns=["channel_name","AverageDuration"])

elif Questions=="10.videos with highest number of comments":
    query10='''select title as videotitle, channel_name as channelname,comments as comments from videos where comments is
                not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df9=pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df9)
